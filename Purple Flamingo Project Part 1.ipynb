# %% [markdown]
# ## Daily Electricity Demand (GWh) by U.S. Region
# By: Aileen, Chengpu, and Aria

# %% [markdown]
# We imported the requests package and submitted a request to the EIA API to get the data using the url link. Aria had to have an API key sent to her email to add to the URL for authentication. We printed the json version to make sure it had imported correctly.

# %%
import requests
url = "https://api.eia.gov/v2/electricity/rto/daily-region-sub-ba-data/data/?frequency=daily&data[0]=value&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000&api_key=LTIKgNRTzB9PyNmYCHTfG8sr3A4h2E1RH6O9Swfi"
data_request = requests.get(url)
data = data_request.json()
print(data)
print(data.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import requests
#       2 url = "https://api.eia.gov/v2/electricity/rto/daily-region-sub-ba-data/data/?frequency=daily&data[0]=value&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000&api_key=LTIKgNRTzB9PyNmYCHTfG8sr3A4h2E1RH6O9Swfi"
#       3 data_request = requests.get(url)
#
# ModuleNotFoundError: No module named 'requests'

# %% [markdown]
# Noticed something was off when running json commands, so figured out it imported as type "dict."

# %%
import pandas as pd
type(data)
# Out:
# dict

# %% [markdown]
# Converted it to a normalized json. Then, I imported the data, which was nested inside the root key, "response," and within that, in a key "data." Then, I convered and printed the first few rows of the dataframe.

# %%
df = pd.json_normalize(data["response"]["data"])
df = pd.DataFrame(df)
type(df)
print(df.shape)
df.head()
# Out:
# (5000, 8)
#        period subba                subba-name parent  \
# 0  2026-02-17  PGAE  Pacific Gas and Electric   CISO
# 1  2026-02-17  PGAE  Pacific Gas and Electric   CISO
# 2  2026-02-17  PGAE  Pacific Gas and Electric   CISO
# 3  2026-02-17  PGAE  Pacific Gas and Electric   CISO
# 4  2026-02-17  PGAE  Pacific Gas and Electric   CISO
#
#                               parent-name  timezone   value    value-units
# 0  California Independent System Operator   Arizona  285432  megawatthours
# 1  California Independent System Operator   Central  285105  megawatthours
# 2  California Independent System Operator   Eastern  284623  megawatthours
# 3  California Independent System Operator  Mountain  285432  megawatthours
# 4  California Independent System Operator   Pacific  285907  megawatthours

# %% [markdown]
# Converted the demand float type and made a new column with the generation figure divided by 1000 so that the unit is gigawatt hours rather than megawatt hours (smaller numbers, easier to read).

# %%
df["value"] = df["value"].astype(float)
df["valueGWh"] = df["value"] / 1000

# %% [markdown]
# Here, we made a new data frame aggregating by date and region the total amount of generation. Now we have a data frame with three columns, date, region, and demand in gigawatts

# %%
new_df = (
    df.groupby(["period", "parent"])
    .agg(Demand=("valueGWh", "sum"))
    .reset_index()
)
print(new_df)
new_df.shape
# Out:
#          period parent    Demand
# 0    2026-02-03   CISO  2944.611
# 1    2026-02-03   ERCO  3800.828
# 2    2026-02-04   CISO  2970.943
# 3    2026-02-04   ERCO  6082.567
# 4    2026-02-04   ISNE  1901.063
# ..          ...    ...       ...
# 96   2026-02-17   CISO  3136.398
# 97   2026-02-17   MISO  1692.924
# 98   2026-02-17   NYIS   432.930
# 99   2026-02-17    PNM   159.490
# 100  2026-02-17   SWPP  1590.912
#
# [101 rows x 3 columns]
# (101, 3)

# %% [markdown]
# Did pretty much all the same steps so that we have a data frame with three columns: date, fuel type, and demand. This shows us, across the US, how much of each fuel type was consumed each day. This dataset also shows generation by balancing authority, or the responsible entity that maintains real-time, instantaneous balance between electricity supply (generation) and demand (load) within a designated grid area. If we want to combine these two datasets to make a visualization eventually, we will need to also find a key that matches balancing authority to grid region (aka parent or ISO).

# %%
url2 = "https://api.eia.gov/v2/electricity/rto/daily-fuel-type-data/data/?frequency=daily&data[0]=value&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000&api_key=LTIKgNRTzB9PyNmYCHTfG8sr3A4h2E1RH6O9Swfi"
data_request2 = requests.get(url2)
data2 = data_request2.json()
print(data2)
# Out:
# {'warnings': [{'warning': 'incomplete return', 'description': 'The API can only return 5000 rows in JSON format.  Please consider constraining your request with facet, start, or end, or using offset to paginate results.'}], 'response': {'total': '5159839', 'dateFormat': 'YYYY-MM-DD', 'frequency': 'daily', 'data': [{'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'COL', 'type-name': 'Coal', 'timezone': 'Arizona', 'timezone-description': 'Arizona', 'value': '35981', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'COL', 'type-name': 'Coal', 'timezone': 'Central', 'timezone-description': 'Central', 'value': '36625', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'COL', 'type-name': 'Coal', 'timezone': 'Eastern', 'timezone-description': 'Eastern', 'value': '37275', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'COL', 'type-name': 'Coal', 'timezone': 'Mountain', 'timezone-description': 'Mountain', 'value': '35981', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'COL', 'type-name': 'Coal', 'timezone': 'Pacific', 'timezone-description': 'Pacific', 'value': '35981', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'NG', 'type-name': 'Natural Gas', 'timezone': 'Arizona', 'timezone-description': 'Arizona', 'value': '11670', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'NG', 'type-name': 'Natural Gas', 'timezone': 'Central', 'timezone-description': 'Central', 'value': '11677', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'NG', 'type-name': 'Natural Gas', 'timezone': 'Eastern', 'timezone-description': 'Eastern', 'value': '11673', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'NG', 'type-name': 'Natural Gas', 'timezone': 'Mountain', 'timezone-description': 'Mountain', 'value': '11670', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'NG', 'type-name': 'Natural Gas', 'timezone': 'Pacific', 'timezone-description': 'Pacific', 'value': '11670', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'WND', 'type-name': 'Wind', 'timezone': 'Arizona', 'timezone-description': 'Arizona', 'value': '14698', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'WND', 'type-name': 'Wind', 'timezone': 'Central', 'timezone-description': 'Central', 'value': '14446', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'WND', 'type-name': 'Wind', 'timezone': 'Eastern', 'timezone-description': 'Eastern', 'value': '14220', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name': 'Associated Electric Cooperative, Inc.', 'fueltype': 'WND', 'type-name': 'Wind', 'timezone': 'Mountain', 'timezone-description': 'Mountain', 'value': '14698', 'value-units': 'megawatthours'}, {'period': '2026-02-17', 'respondent': 'AECI', 'respondent-name' ...

# %%
df2 = pd.json_normalize(data2["response"]["data"])
df2 = pd.DataFrame(df2)
type(df2)
print(df2.shape)
df2.head()
# Out:
# (5000, 9)
#        period respondent                        respondent-name fueltype  \
# 0  2026-02-17       AECI  Associated Electric Cooperative, Inc.      COL
# 1  2026-02-17       AECI  Associated Electric Cooperative, Inc.      COL
# 2  2026-02-17       AECI  Associated Electric Cooperative, Inc.      COL
